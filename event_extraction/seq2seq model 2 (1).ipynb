# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
# Out:
# WARNING:tensorflow:From C:\Users\crist\anaconda3\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Load the data
train_data = pd.read_csv('C:/Users/crist/Desktop/IS450/train.csv', encoding = 'latin1')
test_data = pd.read_csv('C:/Users/crist/Desktop/IS450/test.csv', encoding = 'latin1')

# %%
# Preprocessing
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

tokenizer_article = Tokenizer(oov_token='<OOV>')
tokenizer_event = Tokenizer(oov_token='<OOV>')

# Remove stop words
def remove_stop_words(text):
    tokens = text.split()
    tokens = [word for word in tokens if word.lower() not in stop_words]
    return ' '.join(tokens)

train_data['article'] = train_data['article'].apply(remove_stop_words)
# Fill missing values with an empty string
train_data['event_description'] = train_data['event_description'].fillna('')

# Apply the remove_stop_words function
train_data['event_description'] = train_data['event_description'].apply(remove_stop_words)

#train_data['event_description'] = train_data['event_description'].apply(remove_stop_words)
test_data['article'] = test_data['article'].apply(remove_stop_words)
#test_data['event_description'] = test_data['event_description'].apply(remove_stop_words)

tokenizer_article.fit_on_texts(train_data['article'])
tokenizer_event.fit_on_texts(train_data['event_description'])

vocab_size_article = len(tokenizer_article.word_index) + 1
vocab_size_event = len(tokenizer_event.word_index) + 1

max_article_length = max([len(article.split()) for article in train_data['article']])
max_event_length = max([len(event.split()) for event in train_data['event_description']])

# Check tokenized word indices for articles
print("Word indices for articles:")
print(tokenizer_article.word_index)

# Check tokenized word indices for event descriptions
print("\nWord indices for event descriptions:")
print(tokenizer_event.word_index)
# Out:
# Word indices for articles:
# {'<OOV>': 1, 'market': 2, 'cisco': 3, 'growth': 4, 'ai': 5, 'systems': 6, 'cloud': 7, 'security': 8, 'data': 9, 'inc': 10, '1': 11, '0': 12, 'solutions': 13, 'company': 14, 'services': 15, 'year': 16, '2023': 17, 'industry': 18, 'companies': 19, 'digital': 20, 'global': 21, 'million': 22, 'business': 23, 'technology': 24, 'revenue': 25, '2': 26, 'research': 27, 'report': 28, 'infrastructure': 29, 'technologies': 30, '2024': 31, '3': 32, 'stock': 33, '4': 34, 'us': 35, 'key': 36, 'content': 37, 'price': 38, 'software': 39, 'based': 40, 'access': 41, 'new': 42, 'billion': 43, '5': 44, '2022': 45, 'cyber': 46, 'businesses': 47, 'also': 48, 'analysis': 49, 'america': 50, 'across': 51, 'management': 52, 'high': 53, 'forecast': 54, 'insights': 55, 'nvidia': 56, 's': 57, '7': 58, 'time': 59, 'networks': 60, 'com': 61, 'networking': 62, 'demand': 63, 'like': 64, 'dow': 65, 'platform': 66, 'service': 67, 'period': 68, 'investors': 69, 'quarter': 70, 'euros': 71, 'leading': 72, 'one': 73, 'customers': 74, 'stocks': 75, 'csco': 76, 'sales': 77, '6': 78, 'intelligence': 79, 'including': 80, 'years': 81, 'equipment': 82, 'organizations': 83, 'potential': 84, 'share': 85, 'last': 86, 'information': 87, 'end': 88, 'landscape': 89, 'trends': 90, 'communication': 91, 'largest': 92, 'average': 93, 'said': 94, 'growing': 95, 'opportunities': 96, 'north': 97, '500': 98, 'products': 99, 'earnings': 100, 'network': 101, 'net': 102, 'interest': 
11': 221, 'highest': 222, 'composite': 223, 'ceo': 224, 'great': 225, 'control': 226, 'operating': 227, 'players': 228, 'ended': 229, 'large': 230, 'machine': 231, 'artificial': 232, 'transformation': 233, 'expansion': 234, 'communication': 235, 'advanced': 236, 'month': 237, 'products': 238, '2021': 239, 'managed': 240, 'compound': 241, 'power': 242, 'drive': 243, 'buy': 244, 'leader': 245, 'co': 246, 'focused': 247, 'stronger': 248, 'electronic': 249, '25': 250, 'edge': 251, 'could': 252, 'might': 253, 'ltd': 254, 'recently': 255, 'apple': 256, 'added': 257, 'available': 258, "nvidia's": 259, 'intel': 260, 'projected': 261, 'target': 262, 'privacy': 263, 'globally': 264, 'challenges': 265, 'two': 266, 'increase': 267, 'semiconductor': 268, 'segmented': 269, 'application': 270, 'type': 271, 'amo ...
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\crist\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(test_data.columns)
# Out:
# Index(['article', 'event_description'], dtype='object')

# %%
#Prepare data for training
def prepare_data(data, tokenizer_article, tokenizer_event, max_article_length, max_event_length):
    encoder_input_data = tokenizer_article.texts_to_sequences(data['article'])
    decoder_input_data = tokenizer_event.texts_to_sequences(data['event_description'])

    encoder_input_data = pad_sequences(encoder_input_data, maxlen=max_article_length, padding='post')
    decoder_input_data = pad_sequences(decoder_input_data, maxlen=max_event_length, padding='post')

    decoder_target_data = np.zeros((len(data), max_event_length, vocab_size_event), dtype='float32')
    for i, seq in enumerate(decoder_input_data):
        for j, token_id in enumerate(seq):
            if j > 0:
                decoder_target_data[i][j-1][token_id] = 1.0

    return encoder_input_data, decoder_input_data, decoder_target_data

encoder_input_train, decoder_input_train, decoder_target_train = prepare_data(train_data, tokenizer_article, tokenizer_event, max_article_length, max_event_length)
encoder_input_test, decoder_input_test, decoder_target_test = prepare_data(test_data, tokenizer_article, tokenizer_event, max_article_length, max_event_length)

# %%
# Define the model
latent_dim = 256

# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(vocab_size_article, latent_dim, mask_zero=True)(encoder_inputs)
encoder_lstm = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(vocab_size_event, latent_dim, mask_zero=True)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(vocab_size_event, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)
# Out:
# WARNING:tensorflow:From C:\Users\crist\anaconda3\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
# Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit([encoder_input_train, decoder_input_train], decoder_target_train, batch_size=64, epochs=5, validation_split=0.2)
# Out:
# WARNING:tensorflow:From C:\Users\crist\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\crist\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\crist\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 2/2 [==============================] - 34s 9s/step - loss: 8.0284 - accuracy: 5.9923e-04 - val_loss: 8.0274 - val_accuracy: 0.0112
# Epoch 2/5
# 2/2 [==============================] - 24s 6s/step - loss: 8.0248 - accuracy: 0.0128 - val_loss: 8.0250 - val_accuracy: 0.0236
# Epoch 3/5
# 2/2 [==============================] - 27s 6s/step - loss: 8.0205 - accuracy: 0.0240 - val_loss: 8.0196 - val_accuracy: 0.0183
# Epoch 4/5
# 2/2 [==============================] - 28s 6s/step - loss: 8.0114 - accuracy: 0.0149 - val_loss: 7.9859 - val_accuracy: 0.0177
# Epoch 5/5
# 2/2 [==============================] - 30s 6s/step - loss: 7.9495 - accuracy: 0.0143 - val_loss: 7.8574 - val_accuracy: 0.0177

# %%
# Evaluate the model
score = model.evaluate([encoder_input_test, decoder_input_test], decoder_target_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

# %%
# Generate predictions on the test data
decoder_target_pred = model.predict([encoder_input_test, decoder_input_test])

# Convert predictions to text
def sequences_to_texts(sequences, tokenizer):
    texts = []
    for sequence in sequences:
        text = tokenizer.sequences_to_texts([sequence])[0]
        texts.append(text)
    return texts

decoder_target_pred_texts = sequences_to_texts(np.argmax(decoder_target_pred, axis=2), tokenizer_event)


#def preprocess_text1(text):
    # Convert text to lowercase
    #text = text.lower()
    # Remove punctuation
    # text = ''.join([char for char in text if char not in string.punctuation])
    # Remove stop words
    #text = ' '.join([word for word in text.split() if word.lower() not in stop_words])
    #return text

#for i in range(len(encoder_input_test)):
    #print("Article:", test_data['article'].iloc[i])
    #print("Predicted Event Description:", decoder_target_pred_texts[i])
    #print("Actual Event Description (without tokenization and stop words removed):")
    #print(preprocess_text1(test_data['event_description'].iloc[i]))
    #print("\n")

# Analyze predicted words and extract sentences containing them
predicted_sentences = []
for i, text in enumerate(decoder_target_pred_texts):
    predicted_word = text.split()[0]  # Extract the first word from the predicted text
    article_sentences = test_data['article'].iloc[i].split('.')  # Split the article into sentences
    # Find sentences containing the predicted word
    relevant_sentences = [sentence.strip() for sentence in article_sentences if predicted_word in sentence]
    predicted_sentences.append(relevant_sentences)

# Print predicted sentences
print("Predicted Sentences:")
for i, sentences in enumerate(predicted_sentences):
    print("Article:", test_data['article'].iloc[i])
    print("Predicted Sentences:")
    for sentence in sentences:
        print(sentence)
    print("Actual Event Description:")
    print(test_data['event_description'].iloc[i])
    print("\n")
# Out:
# 1/1 [==============================] - 1s 989ms/step
# Predicted Sentences:
# Article: Pioneering tech expert former Apple Inc. executive Saori Casey reportedly set assume role chief financial officer smart speaker manufacturer Sonos Inc. SONO, marking another significant executive departure Apple. Happened: Casey succeed Eddie Lazarus CFO Jan. 22. Meanwhile, Lazarus shift gears become chief strategy officer continuing role chief legal officer, according statement made developer manufacturer audio products. Casey impressive track record Apple, helmed vice president finance position decade. managed financial planning, forecasting, investor relations Apple, reported Bloomberg. Casey's transition comes Sonos venturing new markets headphones, following slowdown primary smart audio equipment sector. Matters: Casey's move Sonos latest series executive departures Apple. Tang Tan, Apple iPhone design executive, set leave tech giant February join groundbreaking AI project. Previously reported Tan collaborate Jony Ive, founder design studio LoveFrom, Sam Altman, CEO OpenAI, project. December, also reported Steve Hotelling, Apple's vice president, hardware boss Johny Srouji, also decided retire company. Photo Courtesy: Niks Evalds Shutterstock.com Check Benzinga's Consumer Tech coverage following link. Read Next: Samsung Reigns US Patents, Tesla Stays Out: Apple, Qualcomm, IBM Compare? content partially produced help Benzinga Neuro reviewed published Benzinga editors.
# Predicted Sentences:
# Casey's transition comes Sonos venturing new markets headphones, following slowdown primary smart audio equipment sector
# Actual Event Description:
# Saori Casey is reportedly set to assume the role of chief financial officer at smart speaker manufacturer Sonos Inc. SONO, marking another significant executive departure from Apple. Casey will succeed Eddie Lazarus as CFO on Jan. 22. Meanwhile, Lazarus will shift gears to become the chief strategy officer while continuing his role as the chief legal officer. Casey has an impressive track record with Apple, having helmed the vice president of finance position for over a decade. She managed financial planning, forecasting, and investor relations at Apple. Previously, she held various finance roles at Cisco Systems Inc. during a period of substantial growth. Commenting on the appointment, Sonos CEO Patrick Spence said, 'Her experience at world-class companies like Apple and Cisco make her perfectly suited to build on our momentum and seize the opportunity ahead.' Casey's transition comes as Sonos is venturing into new markets such as headphones, following a slowdown in its primary smart audio equipment sector. Casey's move to Sonos is the latest in a series of executive departures from Apple. Tang Tan, an Apple iPhone design executive, is set to leave the tech giant in February to join a groundbreaking AI project. In December, it was also reported that Steve Hotelling, Apple's vice president, who was under hardware boss Johny Srouji, had also decided to retire from the company.
#
#
# Article: Juniper Networks' shares climbed 23% premarket trading Tuesday reports Hewlett Packard Enterprise nearing $13 billion deal networking gear maker capitalize boom artificial intelligence. deal could announced early week, person familiar matter told Reuters Monday. HPE, grappling sluggish demand traditional server business, looking tap Juniper's offerings network security AI-enabled enterprise networking operations (AIOps). Revenue Mist AI, Juniper's cloud-based AI platform helps enterprises streamline operations across wireless wired networks, nearly doubled "last couple quarters", CEO Rami Rahim said December. "Taking Mist secret sauce expanding across layers network definitely part strategy," said. companies struggled pandemic-induced demand surge ebbed HPE, broader portfolio products, able navigate slowdown better Juniper. Weak demand inflation-hit wireless carriers cable operators, well stiff competition Cisco Systems Nvidia networking space drag Juniper. Shares Sunnyvale, California-based Juniper declined 17% 2022 2023, underperforming Nasdaq Composite index. Juniper market value $9.6 billion last close $30.22. company's shares trading $37.25 Tuesday, Hewlett Packard Enterprise's stock fell nearly 8%. Juniper's price-to-earnings ratio next twelve months 12.95, compared Cisco's 12.80, according LSEG data.
# Predicted Sentences:
# Juniper Networks' shares climbed 23% premarket trading Tuesday reports Hewlett Packard Enterprise nearing $13 billion deal networking gear maker capitalize boom artificial intelligence
# Juniper market value $9
# Actual Event Description:
# A deal could be announced as early as this week, a person familiar with the matter told Reuters on Monday. Revenue from Mist AI, Juniper's cloud-based AI platform that helps enterprises streamline operations across wireless and wired networks, has nearly doubled over the 'last couple of quarters', CEO Rami Rahim said in December. Weak demand from inflation-hit wireless carriers and cable operators, as well as stiff competition from Cisco Systems and Nvidia in the networking space has been a drag on Juniper. Shares of Sunnyvale, California-based Juniper have declined over 17% through 2022 and 2023, underperforming the Nasdaq Composite index. Juniper's price-to-earnings ratio for the next twelve months is 12.95, compared to Cisco's 12.80, according to LSEG data.
#
#
# Vornado Realty Trust today named Cushman & Wakefield as the exclusive leasing agent of PENN 2, its 1.8 million square-foot PENN DISTRICT office tower. PENN 2 has been completely transformed into a world-class office environment geared toward today's leading companies. The $750 million full-building redevelopment includes a highly efficient modern glass curtain wall; a striking triple-height lobby; 16 distinctive double-height outdoor tenant loggias; and a signature six story podium comprised of 105,000 square feet of column-free, double-height space. The project also features 72,000 square feet of outdoor green spaces including a massive outdoor terrace atop the podium and a lushly landscaped 17,000 square-foot private rooftop park serviced by an indoor glass pavilion that will be available to all tenants.
#
#
# Article: CHICAGO, Jan. 08, 2024 - Telehealth & Telemedicine market terms revenue estimated worth $120.4 Billion 2023 poised reach $285.7 billion 2028, growing CAGR 23.2% 2023 2028 according latest report published MarketsandMarkets. Growth telehealth telemedicine market mainly driven factors rising population, increasing need expand healthcare access, growing prevalence chronic diseases conditions, shortage physicians, advancements telecommunications, rising level government support, increasing awareness. However, regional variations regulations, fraud, use social media care provision affect market growth negatively forecast period. cloud-based delivery mode expected account largest share 78.2% global telehealth telemedicine market 2022, projected reach USD 243.3 billion 2028 68.5 billion 2023. Based component segment, telehealth telemedicine market segmented software & services type, Software services offering hardware. Based Application, teleradiology segment expected account largest share 22.2% global telehealth telemedicine market 2022. 2021, Medtronic forged partnership Statis Lab Inc., aiming introduce patient monitoring system India. Koninklijke Philips unveiled new products, Patch, Maternal Pod, Avalon CL Fetalin 2020 remote patient monitoring across New Zealand, Europe, Singapore, United States, Australia. 2020, BioTelemetry completed acquisition various healthcare services products Envolve, encompassing coaching platform remote patient monitoring. strategic move concentrated addressing healthcare needs hypertension, mental health, diabetes, chronic heart failure.
# Predicted Sentences:
# 08, 2024 - Telehealth & Telemedicine market terms revenue estimated worth $120
# Growth telehealth telemedicine market mainly driven factors rising population, increasing need expand healthcare access, growing prevalence chronic diseases conditions, shortage physicians, advancements telecommunications, rising level government support, increasing awareness
# However, regional variations regulations, fraud, use social media care provision affect market growth negatively forecast period
# 2% global telehealth telemedicine market 2022, projected reach USD 243
# Based component segment, telehealth telemedicine market segmented software & services type, Software services offering hardware
# 2% global telehealth telemedicine market 2022
# Actual Event Description:
# Telehealth & Telemedicine market in terms of revenue was estimated to be worth $120.4 Billion in 2023 and is poised to reach $285.7 billion by 2028, growing at a CAGR of 23.2% from 2023 to 2028. In 2021, Medtronic forged a partnership with Statis Lab Inc., aiming to introduce a patient monitoring system in India. Koninklijke Philips unveiled new products, such as Patch, Maternal Pod, and Avalon CL Fetalin 2020 for remote patient monitoring across New Zealand, Europe, Singapore, the United States, and Australia. In 2020, BioTelemetry completed the acquisition of various healthcare services and products from Envolve, encompassing a coaching platform and remote patient monitoring.
#
#
# Article: many people think tech companies, think growth stocks. makes sense, considering many top growth stocks past couple decades tech companies. However, plenty tech companies also provide reliable income via dividends. Many larger tech companies cash cows, allowing reward shareholders aside stock price appreciation (which guaranteed). looking dividend-paying tech stocks, following three good options above-average yields. 1. International Business Machines International Business Machines (IBM -0.30%), better known IBM, get attention "Magnificent Seven" stocks do, tech titan right while. Artificial intelligence (AI) made way mainstream 2023, IBM one pioneers technology, dating back 1950s. IBM's quarterly dividend $1.66, trailing-12-month yield around 4.4% -- around 3 times higher S&P 500 span. IBM increased annual dividend 28 consecutive years, there's reason believe change anytime soon. free cash flow enough cover dividend obligations. Although IBM's stock finished 2023 14%, underperformed S&P 500 9%. recent stock price underperformance years attributed transition away legacy businesses like on-premise products high-growth industries like cloud cybersecurity. transformation quickest, high-growth areas highly competitive, IBM making significant investments make happen. meantime, lucrative dividend help investors practice bit patience transformation takes place. 2. Cisco Systems Cisco Systems (CSCO 1.23%) became $200 billion company today networking hardware, including routers modems, security products, switches. since expanded business include services cloud, Internet Things (IoT), cybersecurity industries. Cisco's year-over-year revenue growth slowed previous quarters, attributed enterprise customers deploying hardware slower usual. happens, Cisco may recognize revenue (meaning record financial statements) later quarters. Cisco's latest earnings call, CEO Chuck Robbins noted lag could affect company's revenue "next couple quarters." Unlike many big tech stocks, Cisco's stock see explosive growth 2023, increasing 5%. Thankfully, above-average dividend pick slack. Cisco's quarterly dividend $0.39, trailing-12-month yield 3%. Cisco facing near-term problems, attractive dividend low valuation (forward price-to-earnings ratio 13) give much upside downside long term. 3. Taiwan Semiconductor Manufacturing Taiwan Semiconductor Manufacturing (TSM -1.90%) (or TSMC) global leader semiconductor (chip) production. foundry model -- involves making chips clients' specific needs instead general sales -- driven company become one important tech companies world. clients include Apple (iPhone), Nvidia (GPUs), Tesla (electric vehicle components), many world-class companies. TSMC's quarterly dividend $0.48 (accounting currency conversion rate), yield 1.9%. above-average dividend yield acts true two-for-one benefit, given TSMC's stock price growth potential. past decade, outpaced S&P 500 considerably, AI-fueled boost keep momentum going. TSMC deal directly AI, chips vital many companies do. Without TSMC's chips, advanced computing powers; without advanced computing powers, there's efficient data processing; without efficient data processing, there's AI exists today. Although semiconductor companies, TSMC's chips lead way performance. AI tangible effect TSMC's financials yet, there's way say certain impact it'll have. likely nice addition company integrated many different industries.
# Predicted Sentences:
# Actual Event Description:
# IBM's quarterly dividend is $1.66, with a trailing-12-month yield of around 4.4% -- around 3 times higher than the S&P 500 over that span. IBM has increased its annual dividend for 28 consecutive years. Cisco's quarterly dividend is $0.39, with a trailing-12-month yield of just over 3%. Cisco's year-over-year revenue growth has slowed from previous quarters. During Cisco's latest earnings call, CEO Chuck Robbins noted this lag could affect the company's revenue for the 'next couple of quarters.' Taiwan Semiconductor Manufacturing (TSM -1.90%) (or TSMC) is the global leader in semiconductor (chip) production. TSMC's quarterly dividend is $0.48 (accounting for the currency conversion rate), with a yield of just over 1.9%. Over the past decade, it has outpaced the S&P 500 considerably. TSMC's chips lead the way in performance.
#
#
# Article: Despite macroeconomic challenges, semiconductor industry expected expand time due increased demand advanced technologies AI IoT, well ongoing innovation research. Given industryâs growth prospects, fundamentally strong Broadcom Inc. (AVGO), NVIDIA Corporation (NVDA) Taiwan Semiconductor Manufacturing Company Limited (TSM) could ideal buys solid returns. delving deeper fundamentals, letâs discuss whatâs happening semiconductor industry. semiconductor industry evolving emerging technologies AI, machine learning, IoT, driven worldwide digital consumer electronics usage. technologies driving need advanced powerful semiconductors. result, semiconductor industry expanding rapidly innovating keep pace changing needs. semiconductor robot market United States predicted develop 18.2% CAGR, valuation $817.9 million 2028. Automation rise areas automotive, electronics, healthcare, thanks advances artificial intelligence machine learning, improve manufacturing efficiency. global semiconductor chip market anticipated reach $1.12 trillion 2032, growing CAGR 7.1%. Moreover, investorsâ interest chip stocks evident SPDR S&P Semiconductor ETFâs (XSD) 27.6% returns past three months. Considering conducive trends, letâs look fundamentals three Semiconductor & Wireless Chip stocks, starting number 3. Stock #3: Broadcom Inc. (AVGO) AVGO designs, develops, supplies various semiconductor devices focus complex digital mixed signal complementary metal oxide semiconductor-based devices products worldwide. company operates two segments, Semiconductor Solutions Infrastructure Software. AVGOâs trailing-12-month net income margin 39.31% significantly higher industry average 2.20%. trailing-12-month ROCE 60.31% significantly higher industry average 1.89%. fiscal fourth quarter, ended October 29, 2023, AVGOâs net revenue increased 4.1% year-over-year $9.30 billion, non-GAAP operating income rose 4.5% prior-year quarter $5.75 billion. companyâs non-GAAP net income non-GAAP EPS grew 5.9% 5.8% year-ago value $4.81 billion $11.06, respectively. addition, adjusted EBITDA amounted $6.05 billion, 5.7% year-over-year. Analysts expect AVGOâs revenue increase 39.1% year-over-year $49.83 billion year ending October 2024. EPS expected grow 10.8% year-over-year $46.83 period. expected surpass EPS four trailing quarters. stock gained 114.1% past year close last trading session $1,283.44. AVGOâs POWR Ratings reflect optimistic outlook. POWR Ratings assess stocks 118 different factors, weighting. AVGO grade Quality. Within Semiconductor & Wireless Chip industry, ranked #24 91 stocks. see additional POWR Ratings Growth, Sentiment, Value, Stability Momentum AVGO, click here. Stock #2: NVIDIA Corporation (NVDA) NVDA provides graphics, compute networking solutions U.S., Taiwan, China, internationally. company two segments: Compute & Networking Graphics. February 6, 2024, NVDA partnered together Cisco (CSCO) provide AI infrastructure solutions data center simple deploy operate, providing tremendous processing capacity organizations require succeed AI era. CSCO, industry-leading experience Ethernet networking broad partner ecosystem, NVDA, creator GPU fuelled AI boom, share vision commitment assisting customers transition AI highly secure Ethernet-based infrastructure. NVDAâs trailing-12-month ROTA 34.88% significantly higher industry average 0.66%. 33.23% trailing-12-month ROTC significantly higher 2.44% industry average. fiscal third quarter ended October 29, 2023, NVDAâs revenue non-GAAP gross profit increased 205.5% 308% year-over-year $18.12 billion $13.58 billion, respectively. Moreover, free cash flow stood $7.04 billion, significantly prior-year quarter. quarter, non-GAAP net income non-GAAP net income per share stood $10.02 billion $4.02, 588.2% 593.1% year-ago quarter, respectively. Street expects NVDAâs revenue EPS fiscal first quarter 2024 (ended April 2024) increase 197.3% 340.5% year-over-year $21.38 billion $4.80, respectively. sur ...
# Predicted Sentences:
# semiconductor robot market United States predicted develop 18
# global semiconductor chip market anticipated reach $1
# Author: Rashmi Kumari Rashmi passionate capital markets, wealth management, financial regulatory issues, led pursue career investment analyst
# Actual Event Description:
# Despite macroeconomic challenges, the semiconductor industry is expected to expand over time due to increased demand for advanced technologies such as AI and IoT, as well as ongoing innovation and research. The semiconductor industry is evolving with emerging technologies such as AI, machine learning, and IoT, driven by worldwide digital and consumer electronics usage. The semiconductor robot market in the United States is predicted to develop at an 18.2% CAGR, with a valuation of $817.9 million by 2028. The global semiconductor chip market is anticipated to reach $1.12 trillion by 2032, growing at a CAGR of 7.1%. Moreover, investors interest in chip stocks is evident from the SPDR S&P Semiconductor ETFs (XSD) 27.6% returns over the past three months. For the fiscal fourth quarter, which ended October 29, 2023, AVGOs net revenue increased 4.1% year-over-year to $9.30 billion, while its non-GAAP operating income rose 4.5% from the prior-year quarter to $5.75 billion. The companys non-GAAP net income and non-GAAP EPS grew 5.9% and 5.8% from the year-ago value to $4.81 billion and $11.06, respectively. Analysts expect AVGOs revenue to increase 39.1% year-over-year to $49.83 billion for the year ending October 2024. Its EPS is expected to grow 10.8% year-over-year to $46.83 for the same period. On February 6, 2024, NVDA partnered together with Cisco (CSCO) to provide AI infrastructure solutions for the data center that are simple to deploy and operate, providing the tremendous processing capacity that organizations require to succeed in the AI era. For the fiscal third quarter that ended October 29, 2023, NVDAs revenue and non-GAAP gross profit increased 205.5% and 308% year-over-year to $18.12 billion and $13.58 billion, respectively. Street expects NVDAs revenue and EPS for the fiscal first quarter of 2024 (ended April 2024) to increase 197.3% and 340.5% year-over-year to $21.38 billion and $4.80, respectively. During the fourth quarter, which ended December 31, 2023, TSM reported net revenue of NT$625.53 billion ($19.62 billion). Its net income and EPS amounted to NT$238.31 billion ($7.48 billion) and NT$9.21, respectively. The consensus revenue estimate of $84.60 billion for the year ending December 2024 reflects a 23.6% rise year-over-year. Its EPS is expected to grow 21% year-over-year to $6.27 for the same period
#
#
# Article: Many tech stocks soared past year interest rates stabilized investors eagerly rushed toward AI-related stocks anticipation major AI boom. However, buying frenzy also inflated tech stocks' valuations historical highs. investors wary buying market's priciest tech stocks, might good idea look cheaper value plays pay steady dividends instead. believe three underappreciated blue chip stocks fit bill: IBM (IBM -0.30%), AT&T (T 0.88%), Cisco (CSCO 1.23%). 1. IBM years, IBM considered dead money. first trading day 2011 2021, tech giant's stock declined 16% S&P 500 rallied 191%. underperformed market wide margin struggled grow revenue keep pace evolving cloud market. divested lower-margin businesses generate fresh cash, repeatedly plowed cash wasteful buybacks instead improving core businesses. past three years, IBM's stock rallied 56% CEO Arvind Krishna -- took helm 2020 -- executed aggressive turnaround plan. divested slow-growth managed infrastructure services unit Kyndryl, restructured remaining businesses three simpler units (software, consulting, infrastructure), expanded higher-growth hybrid cloud AI businesses goal generating mid-single digit revenue growth again. strategy required IBM expand Red Hat, acquired 2019, open source software could process data private public clouds. niche approach expanded cloud ecosystem without going head-to-head public cloud leaders like Amazon Microsoft. result, IBM's revenue grew 6% 2022 2% 2023, analysts expect revenue adjusted EPS rise 3% 5%, respectively, 2024. growth rates indicate Big Blue's business finally stabilizing -- still looks like bargain 18 times forward earnings, pays high forward yield 3.6%. 2. AT&T Like IBM, AT&T considered dismal long-term investment. 2021 2022, divested DirecTV Time Warner abandoned ill-fated attempt become media superpower. streamlined business, focused strengthening core telecom business upgrading 5G fiber networks. turnaround effort paid off. total number wireless postpaid subscribers grew 2.9 million 2022 1.7 million 2023, expansion fiber business offset slower growth non-fiber broadband businesses. revenue rose 2% 2022 (excluding divestment U.S. video business) grew 1% 2023. Analysts expect revenue rise 1% 2024 2025. growth rates might seem anemic, indicate AT&T becoming stable blue chip investment again. Meanwhile, AT&T's free cash flow (FCF) rose $14.1 billion 2022 $16.8 billion 2023, expects figure rise $17-$18 billion 2024. healthy FCF growth easily support hefty forward dividend yield 6.6%. Analysts expect adjusted EPS dip 8% 2024 upgrades networks, also anticipate 4% growth 2025 laps higher expenses. seven times forward earnings, AT&T looks dirt cheap relative stable growth rates. 3. Cisco Cisco, world's largest networking company, often considered safe blue-chip tech stock hold economic downturns. past 12 months, stock rose 6% investors fretted near-term slowdown. Cisco's revenue rose 3% fiscal 2022 (which ended July 2022) networking hardware business grappled supply chain constraints. fiscal 2023, revenue jumped 11% overcame constraints finally satisfied market's pent-up demand new networking devices. fiscal 2024, Cisco expects revenue dip 4%-6% nearly flat EPS growth. slowdown caused declining orders across enterprise, service provider, cloud markets. Many customers overcompensated aforementioned supply chain constraints ordering much hardware fiscal 2023, sitting half year shipped orders still waiting deployed. situation might seem bleak, Cisco weathered plenty cyclical downturns supply gluts before. Analysts expect revenue adjusted EPS rise fiscal 2025, stock still looks cheap 13 times forward earnings forward yield 3.1%. low valuation high yield could make good safe play choppy market.
# Predicted Sentences:
# investors wary buying market's priciest tech stocks, might good idea look cheaper value plays pay steady dividends instead
# underperformed market wide margin struggled grow revenue keep pace evolving cloud market
# fiscal 2023, revenue jumped 11% overcame constraints finally satisfied market's pent-up demand new networking devices
# slowdown caused declining orders across enterprise, service provider, cloud markets
# low valuation high yield could make good safe play choppy market
# Actual Event Description:
# Many tech stocks soared over the past year as interest rates stabilized and investors eagerly rushed toward AI-related stocks in anticipation of a major AI boom. But over the past three years, IBM's stock rallied 56% as its CEO Arvind Krishna -- who took the helm in 2020 -- executed an aggressive turnaround plan. As a result, IBM's revenue grew 6% in 2022 and 2% in 2023, and analysts expect its revenue and adjusted EPS to rise 3% and 5%, respectively, in 2024. Its total number of wireless postpaid subscribers grew by 2.9 million in 2022 and 1.7 million in 2023, while the expansion of its fiber business offset the slower growth of its non-fiber broadband businesses. Its revenue rose 2% in 2022 (excluding the divestment of its U.S. video business) and grew 1% in 2023. Analysts expect its revenue to rise 1% in 2024 and 2025. AT&T's free cash flow (FCF) rose from $14.1 billion in 2022 to $16.8 billion in 2023, and it expects that figure to rise to $17-$18 billion in 2024. Analysts expect its adjusted EPS to dip 8% in 2024 as it upgrades its networks, but they also anticipate 4% growth in 2025 as it laps those higher expenses. Cisco's revenue only rose 3% in fiscal 2022 (which ended in July 2022) as its networking hardware business grappled with supply chain constraints. In fiscal 2023, its revenue jumped 11% as it overcame those constraints and finally satisfied the market's pent-up demand for new networking devices. But for fiscal 2024, Cisco expects its revenue to dip 4%-6% with nearly flat EPS growth
